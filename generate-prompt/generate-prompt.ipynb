# %% [markdown]
# # Batch-write items/prompts for psycholinguistic experiments/evaluations of LLMs

# %% [markdown]
# In psycholinguistic experiments and when evaluating LLMs à la Marvin & Linzen (2018), items/prompts vary only for the targeted linguistic phenomenon (e.g., subject-verb agreement). This notebook demonstrates how to batch-write those prompts/items more efficiently using built-in Python functions.
#
# This notebook recreates items from Bott & Noveck (2004). In their study, six different sentence types (listed below) were created with "categories" and "exemplars," expressing semantically or pragmatically true or false statements. The categories used in the study were 'fish,' 'reptile,' 'bird,' 'mammal,' 'insect,' and 'shellfish.' Exemplars included 'anchovies,' 'alligator,' 'eagle,' 'cat,' 'wasp,' and 'winkle.' This notebook generates dictionaries that include entries for text types (i.e., experimental conditions) and prompts/items. See below for examples.
#
# Sentence types from Bott & Noveck (2004):\
# T1 = 'Some {E} are {C}.' \
# T2 = 'Some {C} are {E}.' \
# T3 = 'Some {E} are {WC}.' \
# T4 = 'All {E} are {C}.' \
# T5 = 'All {C} are {E}.' \
# T6 = 'All {E} are {WC}.'
#
# This notebook writes a list of dictionaries in the format of: \
# [{'type': 'TI', 'sentence': 'Some cats are mammals.'} \
# {'type': 'T2', 'sentence': 'Some mammals are cats.'} \
# {'type': 'T3', 'sentence': 'Some cats are fish.'} \
# {'type': 'T4', 'sentence': 'All cats are mammals.'} \
# {'type': 'T5', 'sentence': 'All mammals are cats.'} \
# {'type': 'T6', 'sentence': 'All cats are fish.'}...]

# %%
# For prcessing strings
import nltk
from pattern.en import pluralize

# For saving the output
import json
import csv

# %% [markdown]
# Below, we define some functions to create correct exemplar-category relations and incorrect exemplar-category relations.

# %%
def exemplar_dict(elist,clist):
    """
    Compile correct exemplar and category relations.
    
    Parameters:
        elist: A list of exemplar terms.
        clist: A list of category terms.
    
    Returns:
        dict: {exemplar : category}
    """
    e_dict = {}

    clist_temp = clist + len(clist) * clist

    e_dict = dict(zip(elist,clist_temp))

    return e_dict

# %%
def wrong_category(elist,clist):
    """
    Compile incorrect exemplar and category relations.
    
    Parameters:
        elist: A list of exemplar terms.
        clist: A list of category terms.
    
    Returns:
        dict: {exemplar : ['incorrect category1', 'incorrect category2', ...]}.
    """
    e_dict = exemplar_dict(elist,clist)
    comp_dict = {}
    wc_dict = {}
    
    for i in range(len(clist)):
        comp_dict[clist[i]] = list()

    for i in range(len(comp_dict.keys())):
        for j in range(len(clist)):
            if list(comp_dict)[i] != clist[j]:
                comp_dict[clist[i]].append(clist[j])

    for e, cat1 in e_dict.items():
        for cat2, ls in comp_dict.items():
            if cat1 == cat2:
                wc_dict[e] = ls
    
    return wc_dict

# %%
def T1(e_dict):
    """
    Using correct exemplar and category relations, 
    write items of T1 type, such as "Some cats are mammals.".
    """
    t1 = []
    for e, c in e_dict.items():
         t1.append('Some {E} are {C}.'.format(E = pluralize(e), C = pluralize(c)) )
    return t1

def T2(e_dict):
    """
    Using correct exemplar and category relations, 
    write items of T2 type, such as "Some mammals are cats.".
    """
    t2 = []
    for e, c in e_dict.items():
         t2.append('Some {C} are {E}.'.format(E = pluralize(e), C = pluralize(c)) )
    return t2

def T3(wc_dict):
    """
    Using incorrect exemplar and category relations, 
    write items of T3 type, such as "Some cats are fish.".
    """
    t3 = []
    for e, ls in wc_dict.items():
        for wc in range(len(ls)):
             t3.append('Some {E} are {WC}.'.format(E = pluralize(e), WC = pluralize(ls[wc])) )
    return t3

def T4(e_dict):
    """
    Using correct exemplar and category relations,
    write items of T4 type, such as "All cats are mammals.".
    """
    t4 = []
    for e, c in e_dict.items():
         t4.append('All {E} are {C}.'.format(E = pluralize(e), C = pluralize(c)) )
    return t4

def T5(e_dict):
    """
    Using correct exemplar and category relations, 
    write items of T5 type, such as "All mammals are cats.".
    """
    t5 = []
    for e, c in e_dict.items():
         t5.append('All {C} are {E}.'.format(E = pluralize(e), C = pluralize(c)) )
    return t5

def T6(wc_dict):
    """
    Using incorrect exemplar and category relations, 
    write items of T6 type, such as "All cats are fish.".
    """
    t6 = []
    for e, ls in wc_dict.items():
        for wc in range(len(ls)):
             t6.append('All {E} are {WC}.'.format(E = pluralize(e), WC = pluralize(ls[wc])) )
    return t6

# %%
# Not a necessay function to create items, but may be useful to generate items into a different formats.

def true_grouping(dic, elist, clist):
    for i in range(len(clist)):
        dic[clist[i]] = elist[i::len(clist)]
            
    return dic

# %%
def write_dict(e_dict, wc_dict):
    """
    Compile T1-T6 sentences into a dictionary.
    """
    items = {}

    items['T1'] = T1(e_dict)
    items['T2'] = T2(e_dict)
    items['T3'] = T3(wc_dict)
    items['T4'] = T4(e_dict)
    items['T5'] = T5(e_dict)
    items['T6'] = T6(wc_dict)

    return items

# %% [markdown]
# Supply exemplar and category words. Note that some entries are edited from Bott & Noveck (2004), to reflect the truthful taxonomy. 'Spider', 'frog', 'salamander' are replaced with 'termite', 'chameleon', 'gecko', respectively.
#
# `split()` function can be changed depending on how the list of words are separated.

# %%
c = 'Fish Reptile Bird Mammal Insect Shellfish'.lower()
c_list = c.split()


e = 'Anchovy Alligator Eagle Cat Wasp Winkle Carp Crocodile Canary Horse Termite Crab Cod Chameleon Crow Dog Cockroach Prawn Haddock Iguana Owl Pig Caterpillar Clam Piranha Lizard Sparrow Elephant Ant Oyster Shark Gecko Peacock Sheep Fly Lobster Salmon Snake Parrot Bear Mosquito Langoustine Tuna Tortoise Pigeon Monkey Butterfly Mussel Trout Tuatara Vulture Cow Beetle Cockle'.lower()
e_list = e.split()

# %%
e_dict = exemplar_dict(e_list, c_list)
wc_dict = wrong_category(e_list, c_list)
i_dict = write_dict(e_dict, wc_dict)

# %% [markdown]
# Compile the items either into a list of dictionaries.

# %%
def write_list(e_dict, wc_dict):
    """
    Compile T1-T6 sentences into a list of dictionaries.
    """
    items = []
    
    for i in range(len(T1(e_dict))):
        items.append({'type': 'TI', 'sentence': T1(e_dict)[i]})
    
    for i in range(len(T2(e_dict))):
        items.append({'type': 'T2', 'sentence': T2(e_dict)[i]})
        
    for i in range(len(T3(wc_dict))):
        items.append({'type': 'T3', 'sentence': T3(wc_dict)[i]})
        
    for i in range(len(T4(e_dict))):
        items.append({'type': 'T4', 'sentence': T4(e_dict)[i]})
        
    for i in range(len(T5(e_dict))):
        items.append({'type': 'T5', 'sentence': T5(e_dict)[i]})
        
    for i in range(len(T6(wc_dict))):
        items.append({'type': 'T6', 'sentence': T6(wc_dict)[i]})

    return items

# %%
i_list = write_list(e_dict, wc_dict)
i_list
# Out:
# [{'type': 'TI', 'sentence': 'Some anchovies are fish.'},
#  {'type': 'TI', 'sentence': 'Some alligators are reptiles.'},
#  {'type': 'TI', 'sentence': 'Some eagles are birds.'},
#  {'type': 'TI', 'sentence': 'Some cats are mammals.'},
#  {'type': 'TI', 'sentence': 'Some wasps are insects.'},
#  {'type': 'TI', 'sentence': 'Some winkles are shellfish.'},
#  {'type': 'TI', 'sentence': 'Some carp are fish.'},
#  {'type': 'TI', 'sentence': 'Some crocodiles are reptiles.'},
#  {'type': 'TI', 'sentence': 'Some canaries are birds.'},
#  {'type': 'TI', 'sentence': 'Some horses are mammals.'},
#  {'type': 'TI', 'sentence': 'Some termites are insects.'},
#  {'type': 'TI', 'sentence': 'Some crabs are shellfish.'},
#  {'type': 'TI', 'sentence': 'Some cod are fish.'},
#  {'type': 'TI', 'sentence': 'Some chameleons are reptiles.'},
#  {'type': 'TI', 'sentence': 'Some crows are birds.'},
#  {'type': 'TI', 'sentence': 'Some dogs are mammals.'},
#  {'type': 'TI', 'sentence': 'Some cockroaches are insects.'},
#  {'type': 'TI', 'sentence': 'Some prawns are shellfish.'},
#  {'type': 'TI', 'sentence': 'Some haddocks are fish.'},
#  {'type': 'TI', 'sentence': 'Some iguanas are reptiles.'},
#  {'type': 'TI', 'sentence': 'Some owls are birds.'},
#  {'type': 'TI', 'sentence': 'Some pigs are mammals.'},
#  {'type': 'TI', 'sentence': 'Some caterpillars are insects.'},
#  {'type': 'TI', 'sentence': 'Some clams are shellfish.'},
#  {'type': 'TI', 'sentence': 'Some piranhas are fish.'},
#  {'type': 'TI', 'sentence': 'Some lizards are reptiles.'},
#  {'type': 'TI', 'sentence': 'Some sparrows are birds.'},
#  {'type': 'TI', 'sentence': 'Some elephants are mammals.'},
#  {'type': 'TI', 'sentence': 'Some ants are insects.'},
#  {'type': 'TI', 'sentence': 'Some oysters are shellfish.'},
#  {'type': 'TI', 'sentence': 'Some sharks are fish.'},
#  {'type': 'TI', 'sentence': 'Some geckoes are reptiles.'},
#  {'type': 'TI', 'sentence': 'Some peacocks are birds.'},
#  {'type': 'TI', 'sentence': 'Some sheep are mammals.'},
#  {'type': 'TI', 'sentence': 'Some flies are insects.'},
#  {'type': 'TI', 'sentence': 'Some lobsters are shellfish.'},
#  {'type': 'TI', 'sentence': 'Some salmon are fish.'},
#  {'type': 'TI', 'sentence': 'Some snakes are reptiles.'},
#  {'type': 'TI', 'sentence': 'Some parrots are birds.'},
#  {'type': 'TI', 'sentence': 'Some bears are mammals.'},
#  {'type': 'TI', 'sentence': 'Some mosquitoes are insects.'},
#  {'type': 'TI', 'sentence': 'Some langoustines are shellfish.'},
#  {'type': 'T2', 'sentence': 'Some fish are anchovies.'},
#  {'type': 'T2', 'sentence': 'Some reptiles are alligators.'},
#  {'type': 'T2', 'sentence': 'Some birds are eagles.'},
#  {'type': 'T2', 'sentence': 'Some mammals are cats.'},
#  {'type': 'T2', 'sentence': 'Some insects are wasps.'},
#  {'type': 'T2', 'sentence': 'Some shellfish are winkles.'},
#  {'type': 'T2', 'sentence': 'Some fish are carp.'},
#  {'type': 'T2', 'sentence': 'Some reptiles are crocodiles.'},
#  {'type': 'T2', 'sentence': 'Some birds are canaries.'},
#  {'type': 'T2', 'sentence': 'Some mammals are horses.'},
#  {'type': 'T2', 'sentence': 'Some insects are termites.'},
#  {'type': 'T2', 'sentence': 'Some shellfish are crabs.'},
#  {'type': 'T2', 'sentence': 'Some fish are cod.'},
#  {'type': 'T2', 'sentence': 'Some reptiles are chameleons.'},
#  {'type': 'T2', 'sentence': 'Some birds are crows.'},
#  {'type': 'T2', 'sentence': 'Some mammals are dogs.'},
#  {'type': 'T2', 'sentence': 'Some insects are cockroaches.'},
#  {'type': 'T2', 'sentence': 'Some shellfish are prawns.'},
#  {'type': 'T2', 'sentence': 'Some fish are haddocks.'},
#  {'type': 'T2', 'sentence': 'Some reptiles are iguanas.'},
#  {'type': 'T2', 'sentence': 'Some birds are owls.'},
#  {'type': 'T2', 'sentence': 'Some mammals are pigs.'},
#  {'type': 'T2', 'sentence': 'Some insects are caterpillars.'},
#  {'type': 'T2', 'sentence': 'Some shellfish are clams.'},
#  {'type': 'T2', 'sentence': 'Some fish are piranhas.'},
#  {'type': 'T2', 'sentence': 'Some reptiles are lizards.'},
#  {'type': 'T2', 'sentence': 'Some birds are sparrows.'},
#  {'type': 'T2', 'sentence': 'Some mammals are elephants.'},
#  {'type': 'T2', 'sentence': 'Some insects are ants.'},
#  {'type': 'T2', 'sentence': 'Some shellfish are oysters.'},
#  {'type': 'T2', 'sentence': 'Some fish are sharks.'},
#  {'type': 'T2', 'sentence': 'Some reptiles are geckoes.'},
#  {'type': 'T2', 'sentence': 'Some birds are peacocks.'},
#  {'type': 'T2', 'sentence': 'Some mammals are sheep.'},
#  {'type': 'T2', 'sentence': 'Some insects are flies.'},
#  {'type': 'T2', 'sentence': 'Some shellfish are lobsters.'},
#  {'type': 'T2', 'sentence': 'Some fish are salmon.'},
#  {'type': 'T2', 'sentence': 'Some reptiles are snakes.'},
#  {'type': 'T2', 'sentence': 'Some birds are parrots.'},
#  {'type': 'T2', 'sentence': 'Some mammals are bears.'},
#  {'type': 'T2', 'sentence': 'Some insects are mosquitoes.'},
#  {'type': 'T2', 'sentence': 'Some shellfish are langoustines.'},
#  {'type': 'T3', 'sentence': 'Some anchovies are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some anchovies are birds.'},
#  {'type': 'T3', 'sentence': 'Some anchovies are mammals.'},
#  {'type': 'T3', 'sentence': 'Some anchovies are insects.'},
#  {'type': 'T3', 'sentence': 'Some anchovies are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some alligators are fish.'},
#  {'type': 'T3', 'sentence': 'Some alligators are birds.'},
#  {'type': 'T3', 'sentence': 'Some alligators are mammals.'},
#  {'type': 'T3', 'sentence': 'Some alligators are insects.'},
#  {'type': 'T3', 'sentence': 'Some alligators are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some eagles are fish.'},
#  {'type': 'T3', 'sentence': 'Some eagles are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some eagles are mammals.'},
#  {'type': 'T3', 'sentence': 'Some eagles are insects.'},
#  {'type': 'T3', 'sentence': 'Some eagles are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some cats are fish.'},
#  {'type': 'T3', 'sentence': 'Some cats are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some cats are birds.'},
#  {'type': 'T3', 'sentence': 'Some cats are insects.'},
#  {'type': 'T3', 'sentence': 'Some cats are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some wasps are fish.'},
#  {'type': 'T3', 'sentence': 'Some wasps are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some wasps are birds.'},
#  {'type': 'T3', 'sentence': 'Some wasps are mammals.'},
#  {'type': 'T3', 'sentence': 'Some wasps are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some winkles are fish.'},
#  {'type': 'T3', 'sentence': 'Some winkles are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some winkles are birds.'},
#  {'type': 'T3', 'sentence': 'Some winkles are mammals.'},
#  {'type': 'T3', 'sentence': 'Some winkles are insects.'},
#  {'type': 'T3', 'sentence': 'Some carp are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some carp are birds.'},
#  {'type': 'T3', 'sentence': 'Some carp are mammals.'},
#  {'type': 'T3', 'sentence': 'Some carp are insects.'},
#  {'type': 'T3', 'sentence': 'Some carp are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some crocodiles are fish.'},
#  {'type': 'T3', 'sentence': 'Some crocodiles are birds.'},
#  {'type': 'T3', 'sentence': 'Some crocodiles are mammals.'},
#  {'type': 'T3', 'sentence': 'Some crocodiles are insects.'},
#  {'type': 'T3', 'sentence': 'Some crocodiles are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some canaries are fish.'},
#  {'type': 'T3', 'sentence': 'Some canaries are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some canaries are mammals.'},
#  {'type': 'T3', 'sentence': 'Some canaries are insects.'},
#  {'type': 'T3', 'sentence': 'Some canaries are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some horses are fish.'},
#  {'type': 'T3', 'sentence': 'Some horses are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some horses are birds.'},
#  {'type': 'T3', 'sentence': 'Some horses are insects.'},
#  {'type': 'T3', 'sentence': 'Some horses are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some termites are fish.'},
#  {'type': 'T3', 'sentence': 'Some termites are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some termites are birds.'},
#  {'type': 'T3', 'sentence': 'Some termites are mammals.'},
#  {'type': 'T3', 'sentence': 'Some termites are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some crabs are fish.'},
#  {'type': 'T3', 'sentence': 'Some crabs are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some crabs are birds.'},
#  {'type': 'T3', 'sentence': 'Some crabs are mammals.'},
#  {'type': 'T3', 'sentence': 'Some crabs are insects.'},
#  {'type': 'T3', 'sentence': 'Some cod are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some cod are birds.'},
#  {'type': 'T3', 'sentence': 'Some cod are mammals.'},
#  {'type': 'T3', 'sentence': 'Some cod are insects.'},
#  {'type': 'T3', 'sentence': 'Some cod are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some chameleons are fish.'},
#  {'type': 'T3', 'sentence': 'Some chameleons are birds.'},
#  {'type': 'T3', 'sentence': 'Some chameleons are mammals.'},
#  {'type': 'T3', 'sentence': 'Some chameleons are insects.'},
#  {'type': 'T3', 'sentence': 'Some chameleons are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some crows are fish.'},
#  {'type': 'T3', 'sentence': 'Some crows are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some crows are mammals.'},
#  {'type': 'T3', 'sentence': 'Some crows are insects.'},
#  {'type': 'T3', 'sentence': 'Some crows are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some dogs are fish.'},
#  {'type': 'T3', 'sentence': 'Some dogs are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some dogs are birds.'},
#  {'type': 'T3', 'sentence': 'Some dogs are insects.'},
#  {'type': 'T3', 'sentence': 'Some dogs are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some cockroaches are fish.'},
#  {'type': 'T3', 'sentence': 'Some cockroaches are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some cockroaches are birds.'},
#  {'type': 'T3', 'sentence': 'Some cockroaches are mammals.'},
#  {'type': 'T3', 'sentence': 'Some cockroaches are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some prawns are fish.'},
#  {'type': 'T3', 'sentence': 'Some prawns are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some prawns are birds.'},
#  {'type': 'T3', 'sentence': 'Some prawns are mammals.'},
#  {'type': 'T3', 'sentence': 'Some prawns are insects.'},
#  {'type': 'T3', 'sentence': 'Some haddocks are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some haddocks are birds.'},
#  {'type': 'T3', 'sentence': 'Some haddocks are mammals.'},
#  {'type': 'T3', 'sentence': 'Some haddocks are insects.'},
#  {'type': 'T3', 'sentence': 'Some haddocks are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some iguanas are fish.'},
#  {'type': 'T3', 'sentence': 'Some iguanas are birds.'},
#  {'type': 'T3', 'sentence': 'Some iguanas are mammals.'},
#  {'type': 'T3', 'sentence': 'Some iguanas are insects.'},
#  {'type': 'T3', 'sentence': 'Some iguanas are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some owls are fish.'},
#  {'type': 'T3', 'sentence': 'Some owls are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some owls are mammals.'},
#  {'type': 'T3', 'sentence': 'Some owls are insects.'},
#  {'type': 'T3', 'sentence': 'Some owls are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some pigs are fish.'},
#  {'type': 'T3', 'sentence': 'Some pigs are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some pigs are birds.'},
#  {'type': 'T3', 'sentence': 'Some pigs are insects.'},
#  {'type': 'T3', 'sentence': 'Some pigs are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some caterpillars are fish.'},
#  {'type': 'T3', 'sentence': 'Some caterpillars are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some caterpillars are birds.'},
#  {'type': 'T3', 'sentence': 'Some caterpillars are mammals.'},
#  {'type': 'T3', 'sentence': 'Some caterpillars are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some clams are fish.'},
#  {'type': 'T3', 'sentence': 'Some clams are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some clams are birds.'},
#  {'type': 'T3', 'sentence': 'Some clams are mammals.'},
#  {'type': 'T3', 'sentence': 'Some clams are insects.'},
#  {'type': 'T3', 'sentence': 'Some piranhas are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some piranhas are birds.'},
#  {'type': 'T3', 'sentence': 'Some piranhas are mammals.'},
#  {'type': 'T3', 'sentence': 'Some piranhas are insects.'},
#  {'type': 'T3', 'sentence': 'Some piranhas are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some lizards are fish.'},
#  {'type': 'T3', 'sentence': 'Some lizards are birds.'},
#  {'type': 'T3', 'sentence': 'Some lizards are mammals.'},
#  {'type': 'T3', 'sentence': 'Some lizards are insects.'},
#  {'type': 'T3', 'sentence': 'Some lizards are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some sparrows are fish.'},
#  {'type': 'T3', 'sentence': 'Some sparrows are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some sparrows are mammals.'},
#  {'type': 'T3', 'sentence': 'Some sparrows are insects.'},
#  {'type': 'T3', 'sentence': 'Some sparrows are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some elephants are fish.'},
#  {'type': 'T3', 'sentence': 'Some elephants are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some elephants are birds.'},
#  {'type': 'T3', 'sentence': 'Some elephants are insects.'},
#  {'type': 'T3', 'sentence': 'Some elephants are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some ants are fish.'},
#  {'type': 'T3', 'sentence': 'Some ants are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some ants are birds.'},
#  {'type': 'T3', 'sentence': 'Some ants are mammals.'},
#  {'type': 'T3', 'sentence': 'Some ants are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some oysters are fish.'},
#  {'type': 'T3', 'sentence': 'Some oysters are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some oysters are birds.'},
#  {'type': 'T3', 'sentence': 'Some oysters are mammals.'},
#  {'type': 'T3', 'sentence': 'Some oysters are insects.'},
#  {'type': 'T3', 'sentence': 'Some sharks are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some sharks are birds.'},
#  {'type': 'T3', 'sentence': 'Some sharks are mammals.'},
#  {'type': 'T3', 'sentence': 'Some sharks are insects.'},
#  {'type': 'T3', 'sentence': 'Some sharks are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some geckoes are fish.'},
#  {'type': 'T3', 'sentence': 'Some geckoes are birds.'},
#  {'type': 'T3', 'sentence': 'Some geckoes are mammals.'},
#  {'type': 'T3', 'sentence': 'Some geckoes are insects.'},
#  {'type': 'T3', 'sentence': 'Some geckoes are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some peacocks are fish.'},
#  {'type': 'T3', 'sentence': 'Some peacocks are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some peacocks are mammals.'},
#  {'type': 'T3', 'sentence': 'Some peacocks are insects.'},
#  {'type': 'T3', 'sentence': 'Some peacocks are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some sheep are fish.'},
#  {'type': 'T3', 'sentence': 'Some sheep are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some sheep are birds.'},
#  {'type': 'T3', 'sentence': 'Some sheep are insects.'},
#  {'type': 'T3', 'sentence': 'Some sheep are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some flies are fish.'},
#  {'type': 'T3', 'sentence': 'Some flies are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some flies are birds.'},
#  {'type': 'T3', 'sentence': 'Some flies are mammals.'},
#  {'type': 'T3', 'sentence': 'Some flies are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some lobsters are fish.'},
#  {'type': 'T3', 'sentence': 'Some lobsters are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some lobsters are birds.'},
#  {'type': 'T3', 'sentence': 'Some lobsters are mammals.'},
#  {'type': 'T3', 'sentence': 'Some lobsters are insects.'},
#  {'type': 'T3', 'sentence': 'Some salmon are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some salmon are birds.'},
#  {'type': 'T3', 'sentence': 'Some salmon are mammals.'},
#  {'type': 'T3', 'sentence': 'Some salmon are insects.'},
#  {'type': 'T3', 'sentence': 'Some salmon are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some snakes are fish.'},
#  {'type': 'T3', 'sentence': 'Some snakes are birds.'},
#  {'type': 'T3', 'sentence': 'Some snakes are mammals.'},
#  {'type': 'T3', 'sentence': 'Some snakes are insects.'},
#  {'type': 'T3', 'sentence': 'Some snakes are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some parrots are fish.'},
#  {'type': 'T3', 'sentence': 'Some parrots are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some parrots are mammals.'},
#  {'type': 'T3', 'sentence': 'Some parrots are insects.'},
#  {'type': 'T3', 'sentence': 'Some parrots are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some bears are fish.'},
#  {'type': 'T3', 'sentence': 'Some bears are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some bears are birds.'},
#  {'type': 'T3', 'sentence': 'Some bears are insects.'},
#  {'type': 'T3', 'sentence': 'Some bears are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some mosquitoes are fish.'},
#  {'type': 'T3', 'sentence': 'Some mosquitoes are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some mosquitoes are birds.'},
#  {'type': 'T3', 'sentence': 'Some mosquitoes are mammals.'},
#  {'type': 'T3', 'sentence': 'Some mosquitoes are shellfish.'},
#  {'type': 'T3', 'sentence': 'Some langoustines are fish.'},
#  {'type': 'T3', 'sentence': 'Some langoustines are reptiles.'},
#  {'type': 'T3', 'sentence': 'Some langoustines are birds.'},
#  {'type': 'T3', 'sentence': 'Some langoustines are mammals.'},
#  {'type': 'T3', 'sentence': 'Some langoustines are insects.'},
#  {'type': 'T4', 'sentence': 'All anchovies are fish.'},
#  {'type': 'T4', 'sentence': 'All alligators are reptiles.'},
#  {'type': 'T4', 'sentence': 'All eagles are birds.'},
#  {'type': 'T4', 'sentence': 'All cats are mammals.'},
#  {'type': 'T4', 'sentence': 'All wasps are insects.'},
#  {'type': 'T4', 'sentence': 'All winkles are shellfish.'},
#  {'type': 'T4', 'sentence': 'All carp are fish.'},
#  {'type': 'T4', 'sentence': 'All crocodiles are reptiles.'},
#  {'type': 'T4', 'sentence': 'All canaries are birds.'},
#  {'type': 'T4', 'sentence': 'All horses are mammals.'},
#  {'type': 'T4', 'sentence': 'All termites are insects.'},
#  {'type': 'T4', 'sentence': 'All crabs are shellfish.'},
#  {'type': 'T4', 'sentence': 'All cod are fish.'},
#  {'type': 'T4', 'sentence': 'All chameleons are reptiles.'},
#  {'type': 'T4', 'sentence': 'All crows are birds.'},
#  {'type': 'T4', 'sentence': 'All dogs are mammals.'},
#  {'type': 'T4', 'sentence': 'All cockroaches are insects.'},
#  {'type': 'T4', 'sentence': 'All prawns are shellfish.'},
#  {'type': 'T4', 'sentence': 'All haddocks are fish.'},
#  {'type': 'T4', 'sentence': 'All iguanas are reptiles.'},
#  {'type': 'T4', 'sentence': 'All owls are birds.'},
#  {'type': 'T4', 'sentence': 'All pigs are mammals.'},
#  {'type': 'T4', 'sentence': 'All caterpillars are insects.'},
#  {'type': 'T4', 'sentence': 'All clams are shellfish.'},
#  {'type': 'T4', 'sentence': 'All piranhas are fish.'},
#  {'type': 'T4', 'sentence': 'All lizards are reptiles.'},
#  {'type': 'T4', 'sentence': 'All sparrows are birds.'},
#  {'type': 'T4', 'sentence': 'All elephants are mammals.'},
#  {'type': 'T4', 'sentence': 'All ants are insects.'},
#  {'type': 'T4', 'sentence': 'All oysters are shellfish.'},
#  {'type': 'T4', 'sentence': 'All sharks are fish.'},
#  {'type': 'T4', 'sentence': 'All geckoes are reptiles.'},
#  {'type': 'T4', 'sentence': 'All peacocks are birds.'},
#  {'type': 'T4', 'sentence': 'All sheep are mammals.'},
#  {'type': 'T4', 'sentence': 'All flies are insects.'},
#  {'type': 'T4', 'sentence': 'All lobsters are shellfish.'},
#  {'type': 'T4', 'sentence': 'All salmon are fish.'},
#  {'type': 'T4', 'sentence': 'All snakes are reptiles.'},
#  {'type': 'T4', 'sentence': 'All parrots are birds.'},
#  {'type': 'T4', 'sentence': 'All bears are mammals.'},
#  {'type': 'T4', 'sentence': 'All mosquitoes are insects.'},
#  {'type': 'T4', 'sentence': 'All langoustines are shellfish.'},
#  {'type': 'T5', 'sentence': 'All fish are anchovies.'},
#  {'type': 'T5', 'sentence': 'All reptiles are alligators.'},
#  {'type': 'T5', 'sentence': 'All birds are eagles.'},
#  {'type': 'T5', 'sentence': 'All mammals are cats.'},
#  {'type': 'T5', 'sentence': 'All insects are wasps.'},
#  {'type': 'T5', 'sentence': 'All shellfish are winkles.'},
#  {'type': 'T5', 'sentence': 'All fish are carp.'},
#  {'type': 'T5', 'sentence': 'All reptiles are crocodiles.'},
#  {'type': 'T5', 'sentence': 'All birds are canaries.'},
#  {'type': 'T5', 'sentence': 'All mammals are horses.'},
#  {'type': 'T5', 'sentence': 'All insects are termites.'},
#  {'type': 'T5', 'sentence': 'All shellfish are crabs.'},
#  {'type': 'T5', 'sentence': 'All fish are cod.'},
#  {'type': 'T5', 'sentence': 'All reptiles are chameleons.'},
#  {'type': 'T5', 'sentence': 'All birds are crows.'},
#  {'type': 'T5', 'sentence': 'All mammals are dogs.'},
#  {'type': 'T5', 'sentence': 'All insects are cockroaches.'},
#  {'type': 'T5', 'sentence': 'All shellfish are prawns.'},
#  {'type': 'T5', 'sentence': 'All fish are haddocks.'},
#  {'type': 'T5', 'sentence': 'All reptiles are iguanas.'},
#  {'type': 'T5', 'sentence': 'All birds are owls.'},
#  {'type': 'T5', 'sentence': 'All mammals are pigs.'},
#  {'type': 'T5', 'sentence': 'All insects are caterpillars.'},
#  {'type': 'T5', 'sentence': 'All shellfish are clams.'},
#  {'type': 'T5', 'sentence': 'All fish are piranhas.'},
#  {'type': 'T5', 'sentence': 'All reptiles are lizards.'},
#  {'type': 'T5', 'sentence': 'All birds are sparrows.'},
#  {'type': 'T5', 'sentence': 'All mammals are elephants.'},
#  {'type': 'T5', 'sentence': 'All insects are ants.'},
#  {'type': 'T5', 'sentence': 'All shellfish are oysters.'},
#  {'type': 'T5', 'sentence': 'All fish are sharks.'},
#  {'type': 'T5', 'sentence': 'All reptiles are geckoes.'},
#  {'type': 'T5', 'sentence': 'All birds are peacocks.'},
#  {'type': 'T5', 'sentence': 'All mammals are sheep.'},
#  {'type': 'T5', 'sentence': 'All insects are flies.'},
#  {'type': 'T5', 'sentence': 'All shellfish are lobsters.'},
#  {'type': 'T5', 'sentence': 'All fish are salmon.'},
#  {'type': 'T5', 'sentence': 'All reptiles are snakes.'},
#  {'type': 'T5', 'sentence': 'All birds are parrots.'},
#  {'type': 'T5', 'sentence': 'All mammals are bears.'},
#  {'type': 'T5', 'sentence': 'All insects are mosquitoes.'},
#  {'type': 'T5', 'sentence': 'All shellfish are langoustines.'},
#  {'type': 'T6', 'sentence': 'All anchovies are reptiles.'},
#  {'type': 'T6', 'sentence': 'All anchovies are birds.'},
#  {'type': 'T6', 'sentence': 'All anchovies are mammals.'},
#  {'type': 'T6', 'sentence': 'All anchovies are insects.'},
#  {'type': 'T6', 'sentence': 'All anchovies are shellfish.'},
#  {'type': 'T6', 'sentence': 'All alligators are fish.'},
#  {'type': 'T6', 'sentence': 'All alligators are birds.'},
#  {'type': 'T6', 'sentence': 'All alligators are mammals.'},
#  {'type': 'T6', 'sentence': 'All alligators are insects.'},
#  {'type': 'T6', 'sentence': 'All alligators are shellfish.'},
#  {'type': 'T6', 'sentence': 'All eagles are fish.'},
#  {'type': 'T6', 'sentence': 'All eagles are reptiles.'},
#  {'type': 'T6', 'sentence': 'All eagles are mammals.'},
#  {'type': 'T6', 'sentence': 'All eagles are insects.'},
#  {'type': 'T6', 'sentence': 'All eagles are shellfish.'},
#  {'type': 'T6', 'sentence': 'All cats are fish.'},
#  {'type': 'T6', 'sentence': 'All cats are reptiles.'},
#  {'type': 'T6', 'sentence': 'All cats are birds.'},
#  {'type': 'T6', 'sentence': 'All cats are insects.'},
#  {'type': 'T6', 'sentence': 'All cats are shellfish.'},
#  {'type': 'T6', 'sentence': 'All wasps are fish.'},
#  {'type': 'T6', 'sentence': 'All wasps are reptiles.'},
#  {'type': 'T6', 'sentence': 'All wasps are birds.'},
#  {'type': 'T6', 'sentence': 'All wasps are mammals.'},
#  {'type': 'T6', 'sentence': 'All wasps are shellfish.'},
#  {'type': 'T6', 'sentence': 'All winkles are fish.'},
#  {'type': 'T6', 'sentence': 'All winkles are reptiles.'},
#  {'type': 'T6', 'sentence': 'All winkles are birds.'},
#  {'type': 'T6', 'sentence': 'All winkles are mammals.'},
#  {'type': 'T6', 'sentence': 'All winkles are insects.'},
#  {'type': 'T6', 'sentence': 'All carp are reptiles.'},
#  {'type': 'T6', 'sentence': 'All carp are birds.'},
#  {'type': 'T6', 'sentence': 'All carp are mammals.'},
#  {'type': 'T6', 'sentence': 'All carp are insects.'},
#  {'type': 'T6', 'sentence': 'All carp are shellfish.'},
#  {'type': 'T6', 'sentence': 'All crocodiles are fish.'},
#  {'type': 'T6', 'sentence': 'All crocodiles are birds.'},
#  {'type': 'T6', 'sentence': 'All crocodiles are mammals.'},
#  {'type': 'T6', 'sentence': 'All crocodiles are insects.'},
#  {'type': 'T6', 'sentence': 'All crocodiles are shellfish.'},
#  {'type': 'T6', 'sentence': 'All canaries are fish.'},
#  {'type': 'T6', 'sentence': 'All canaries are reptiles.'},
#  {'type': 'T6', 'sentence': 'All canaries are mammals.'},
#  {'type': 'T6', 'sentence': 'All canaries are insects.'},
#  {'type': 'T6', 'sentence': 'All canaries are shellfish.'},
#  {'type': 'T6', 'sentence': 'All horses are fish.'},
#  {'type': 'T6', 'sentence': 'All horses are reptiles.'},
#  {'type': 'T6', 'sentence': 'All horses are birds.'},
#  {'type': 'T6', 'sentence': 'All horses are insects.'},
#  {'type': 'T6', 'sentence': 'All horses are shellfish.'},
#  {'type': 'T6', 'sentence': 'All termites are fish.'},
#  {'type': 'T6', 'sentence': 'All termites are reptiles.'},
#  {'type': 'T6', 'sentence': 'All termites are birds.'},
#  {'type': 'T6', 'sentence': 'All termites are mammals.'},
#  {'type': 'T6', 'sentence': 'All termites are shellfish.'},
#  {'type': 'T6', 'sentence': 'All crabs are fish.'},
#  {'type': 'T6', 'sentence': 'All crabs are reptiles.'},
#  {'type': 'T6', 'sentence': 'All crabs are birds.'},
#  {'type': 'T6', 'sentence': 'All crabs are mammals.'},
#  {'type': 'T6', 'sentence': 'All crabs are insects.'},
#  {'type': 'T6', 'sentence': 'All cod are reptiles.'},
#  {'type': 'T6', 'sentence': 'All cod are birds.'},
#  {'type': 'T6', 'sentence': 'All cod are mammals.'},
#  {'type': 'T6', 'sentence': 'All cod are insects.'},
#  {'type': 'T6', 'sentence': 'All cod are shellfish.'},
#  {'type': 'T6', 'sentence': 'All chameleons are fish.'},
#  {'type': 'T6', 'sentence': 'All chameleons are birds.'},
#  {'type': 'T6', 'sentence': 'All chameleons are mammals.'},
#  {'type': 'T6', 'sentence': 'All chameleons are insects.'},
#  {'type': 'T6', 'sentence': 'All chameleons are shellfish.'},
#  {'type': 'T6', 'sentence': 'All crows are fish.'},
#  {'type': 'T6', 'sentence': 'All crows are reptiles.'},
#  {'type': 'T6', 'sentence': 'All crows are mammals.'},
#  {'type': 'T6', 'sentence': 'All crows are insects.'},
#  {'type': 'T6', 'sentence': 'All crows are shellfish.'},
#  {'type': 'T6', 'sentence': 'All dogs are fish.'},
#  {'type': 'T6', 'sentence': 'All dogs are reptiles.'},
#  {'type': 'T6', 'sentence': 'All dogs are birds.'},
#  {'type': 'T6', 'sentence': 'All dogs are insects.'},
#  {'type': 'T6', 'sentence': 'All dogs are shellfish.'},
#  {'type': 'T6', 'sentence': 'All cockroaches are fish.'},
#  {'type': 'T6', 'sentence': 'All cockroaches are reptiles.'},
#  {'type': 'T6', 'sentence': 'All cockroaches are birds.'},
#  {'type': 'T6', 'sentence': 'All cockroaches are mammals.'},
#  {'type': 'T6', 'sentence': 'All cockroaches are shellfish.'},
#  {'type': 'T6', 'sentence': 'All prawns are fish.'},
#  {'type': 'T6', 'sentence': 'All prawns are reptiles.'},
#  {'type': 'T6', 'sentence': 'All prawns are birds.'},
#  {'type': 'T6', 'sentence': 'All prawns are mammals.'},
#  {'type': 'T6', 'sentence': 'All prawns are insects.'},
#  {'type': 'T6', 'sentence': 'All haddocks are reptiles.'},
#  {'type': 'T6', 'sentence': 'All haddocks are birds.'},
#  {'type': 'T6', 'sentence': 'All haddocks are mammals.'},
#  {'type': 'T6', 'sentence': 'All haddocks are insects.'},
#  {'type': 'T6', 'sentence': 'All haddocks are shellfish.'},
#  {'type': 'T6', 'sentence': 'All iguanas are fish.'},
#  {'type': 'T6', 'sentence': 'All iguanas are birds.'},
#  {'type': 'T6', 'sentence': 'All iguanas are mammals.'},
#  {'type': 'T6', 'sentence': 'All iguanas are insects.'},
#  {'type': 'T6', 'sentence': 'All iguanas are shellfish.'},
#  {'type': 'T6', 'sentence': 'All owls are fish.'},
#  {'type': 'T6', 'sentence': 'All owls are reptiles.'},
#  {'type': 'T6', 'sentence': 'All owls are mammals.'},
#  {'type': 'T6', 'sentence': 'All owls are insects.'},
#  {'type': 'T6', 'sentence': 'All owls are shellfish.'},
#  {'type': 'T6', 'sentence': 'All pigs are fish.'},
#  {'type': 'T6', 'sentence': 'All pigs are reptiles.'},
#  {'type': 'T6', 'sentence': 'All pigs are birds.'},
#  {'type': 'T6', 'sentence': 'All pigs are insects.'},
#  {'type': 'T6', 'sentence': 'All pigs are shellfish.'},
#  {'type': 'T6', 'sentence': 'All caterpillars are fish.'},
#  {'type': 'T6', 'sentence': 'All caterpillars are reptiles.'},
#  {'type': 'T6', 'sentence': 'All caterpillars are birds.'},
#  {'type': 'T6', 'sentence': 'All caterpillars are mammals.'},
#  {'type': 'T6', 'sentence': 'All caterpillars are shellfish.'},
#  {'type': 'T6', 'sentence': 'All clams are fish.'},
#  {'type': 'T6', 'sentence': 'All clams are reptiles.'},
#  {'type': 'T6', 'sentence': 'All clams are birds.'},
#  {'type': 'T6', 'sentence': 'All clams are mammals.'},
#  {'type': 'T6', 'sentence': 'All clams are insects.'},
#  {'type': 'T6', 'sentence': 'All piranhas are reptiles.'},
#  {'type': 'T6', 'sentence': 'All piranhas are birds.'},
#  {'type': 'T6', 'sentence': 'All piranhas are mammals.'},
#  {'type': 'T6', 'sentence': 'All piranhas are insects.'},
#  {'type': 'T6', 'sentence': 'All piranhas are shellfish.'},
#  {'type': 'T6', 'sentence': 'All lizards are fish.'},
#  {'type': 'T6', 'sentence': 'All lizards are birds.'},
#  {'type': 'T6', 'sentence': 'All lizards are mammals.'},
#  {'type': 'T6', 'sentence': 'All lizards are insects.'},
#  {'type': 'T6', 'sentence': 'All lizards are shellfish.'},
#  {'type': 'T6', 'sentence': 'All sparrows are fish.'},
#  {'type': 'T6', 'sentence': 'All sparrows are reptiles.'},
#  {'type': 'T6', 'sentence': 'All sparrows are mammals.'},
#  {'type': 'T6', 'sentence': 'All sparrows are insects.'},
#  {'type': 'T6', 'sentence': 'All sparrows are shellfish.'},
#  {'type': 'T6', 'sentence': 'All elephants are fish.'},
#  {'type': 'T6', 'sentence': 'All elephants are reptiles.'},
#  {'type': 'T6', 'sentence': 'All elephants are birds.'},
#  {'type': 'T6', 'sentence': 'All elephants are insects.'},
#  {'type': 'T6', 'sentence': 'All elephants are shellfish.'},
#  {'type': 'T6', 'sentence': 'All ants are fish.'},
#  {'type': 'T6', 'sentence': 'All ants are reptiles.'},
#  {'type': 'T6', 'sentence': 'All ants are birds.'},
#  {'type': 'T6', 'sentence': 'All ants are mammals.'},
#  {'type': 'T6', 'sentence': 'All ants are shellfish.'},
#  {'type': 'T6', 'sentence': 'All oysters are fish.'},
#  {'type': 'T6', 'sentence': 'All oysters are reptiles.'},
#  {'type': 'T6', 'sentence': 'All oysters are birds.'},
#  {'type': 'T6', 'sentence': 'All oysters are mammals.'},
#  {'type': 'T6', 'sentence': 'All oysters are insects.'},
#  {'type': 'T6', 'sentence': 'All sharks are reptiles.'},
#  {'type': 'T6', 'sentence': 'All sharks are birds.'},
#  {'type': 'T6', 'sentence': 'All sharks are mammals.'},
#  {'type': 'T6', 'sentence': 'All sharks are insects.'},
#  {'type': 'T6', 'sentence': 'All sharks are shellfish.'},
#  {'type': 'T6', 'sentence': 'All geckoes are fish.'},
#  {'type': 'T6', 'sentence': 'All geckoes are birds.'},
#  {'type': 'T6', 'sentence': 'All geckoes are mammals.'},
#  {'type': 'T6', 'sentence': 'All geckoes are insects.'},
#  {'type': 'T6', 'sentence': 'All geckoes are shellfish.'},
#  {'type': 'T6', 'sentence': 'All peacocks are fish.'},
#  {'type': 'T6', 'sentence': 'All peacocks are reptiles.'},
#  {'type': 'T6', 'sentence': 'All peacocks are mammals.'},
#  {'type': 'T6', 'sentence': 'All peacocks are insects.'},
#  {'type': 'T6', 'sentence': 'All peacocks are shellfish.'},
#  {'type': 'T6', 'sentence': 'All sheep are fish.'},
#  {'type': 'T6', 'sentence': 'All sheep are reptiles.'},
#  {'type': 'T6', 'sentence': 'All sheep are birds.'},
#  {'type': 'T6', 'sentence': 'All sheep are insects.'},
#  {'type': 'T6', 'sentence': 'All sheep are shellfish.'},
#  {'type': 'T6', 'sentence': 'All flies are fish.'},
#  {'type': 'T6', 'sentence': 'All flies are reptiles.'},
#  {'type': 'T6', 'sentence': 'All flies are birds.'},
#  {'type': 'T6', 'sentence': 'All flies are mammals.'},
#  {'type': 'T6', 'sentence': 'All flies are shellfish.'},
#  {'type': 'T6', 'sentence': 'All lobsters are fish.'},
#  {'type': 'T6', 'sentence': 'All lobsters are reptiles.'},
#  {'type': 'T6', 'sentence': 'All lobsters are birds.'},
#  {'type': 'T6', 'sentence': 'All lobsters are mammals.'},
#  {'type': 'T6', 'sentence': 'All lobsters are insects.'},
#  {'type': 'T6', 'sentence': 'All salmon are reptiles.'},
#  {'type': 'T6', 'sentence': 'All salmon are birds.'},
#  {'type': 'T6', 'sentence': 'All salmon are mammals.'},
#  {'type': 'T6', 'sentence': 'All salmon are insects.'},
#  {'type': 'T6', 'sentence': 'All salmon are shellfish.'},
#  {'type': 'T6', 'sentence': 'All snakes are fish.'},
#  {'type': 'T6', 'sentence': 'All snakes are birds.'},
#  {'type': 'T6', 'sentence': 'All snakes are mammals.'},
#  {'type': 'T6', 'sentence': 'All snakes are insects.'},
#  {'type': 'T6', 'sentence': 'All snakes are shellfish.'},
#  {'type': 'T6', 'sentence': 'All parrots are fish.'},
#  {'type': 'T6', 'sentence': 'All parrots are reptiles.'},
#  {'type': 'T6', 'sentence': 'All parrots are mammals.'},
#  {'type': 'T6', 'sentence': 'All parrots are insects.'},
#  {'type': 'T6', 'sentence': 'All parrots are shellfish.'},
#  {'type': 'T6', 'sentence': 'All bears are fish.'},
#  {'type': 'T6', 'sentence': 'All bears are reptiles.'},
#  {'type': 'T6', 'sentence': 'All bears are birds.'},
#  {'type': 'T6', 'sentence': 'All bears are insects.'},
#  {'type': 'T6', 'sentence': 'All bears are shellfish.'},
#  {'type': 'T6', 'sentence': 'All mosquitoes are fish.'},
#  {'type': 'T6', 'sentence': 'All mosquitoes are reptiles.'},
#  {'type': 'T6', 'sentence': 'All mosquitoes are birds.'},
#  {'type': 'T6', 'sentence': 'All mosquitoes are mammals.'},
#  {'type': 'T6', 'sentence': 'All mosquitoes are shellfish.'},
#  {'type': 'T6', 'sentence': 'All langoustines are fish.'},
#  {'type': 'T6', 'sentence': 'All langoustines are reptiles.'},
#  {'type': 'T6', 'sentence': 'All langoustines are birds.'},
#  {'type': 'T6', 'sentence': 'All langoustines are mammals.'},
#  {'type': 'T6', 'sentence': 'All langoustines are insects.'}]

# %% [markdown]
# Two options are provided to save the list of dictionaries in JSON or CSV, which preserve the dictionary format and complement well with pandas library for the future usage.

# %%
with open('item_dict.json', 'w') as write:
    json.dump(i_dict, write)

# To open the JSON file
with open('item_dict.json', 'r') as read:
    i_dict = json.load(read)

# %%
with open('item_list.csv', 'w', newline = '') as write:
    w = csv.DictWriter(write, fieldnames = i_list[0].keys())
    w.writeheader()
    w.writerows(i_list)
